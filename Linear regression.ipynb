# %%
import tensorflow as tf

# %% [markdown]
# ### 1. Create regression dataset, build and fit a model to it. ###

# %%
# Creating data points
X = tf.cast(tf.range(0, 21), dtype=tf.float32)

y = 2*X - 5

# reshaping X:
X = tf.expand_dims(X, axis = -1)
print(X.shape)
# Out:
# (21, 1)

# %%
# Building and fitting a first model

model_0 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model_0.compile(
    optimizer = tf.keras.optimizers.SGD(),
    loss = tf.keras.losses.MeanAbsoluteError(),
    metrics = ['mae']
)

model_0.fit(X, y, epochs = 500, verbose = False)

# %%
model_0.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Summary of model's layers
from tensorflow.keras.utils import plot_model

plot_model(model_0, show_shapes = True)

# %%
# Calculated weight and bias
weight, bias = model_0.layers[0].get_weights()

print(weight, bias)
# Out:
# [[1.8001926]] [-2.0838044]

# %% [markdown]
# ### 2. Building a neural network with 4 Dense layers and fitting it to regression dataset ###

# %%
# Create a model with 4 layers

model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(4),
    tf.keras.layers.Dense(4),
    tf.keras.layers.Dense(4),
    tf.keras.layers.Dense(1)

])

model_1.compile(
    loss = tf.keras.losses.MeanAbsoluteError(),
    optimizer = tf.keras.optimizers.Adam(learning_rate = 0.01),
    metrics = ['mae']
)

model_1.fit(X, y, epochs = 100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 621ms/step - loss: 32.0561 - mae: 32.0561
# Epoch 2/100
# 1/1 [==============================] - 0s 7ms/step - loss: 29.5072 - mae: 29.5072
# Epoch 3/100
# 1/1 [==============================] - 0s 8ms/step - loss: 27.0643 - mae: 27.0643
# Epoch 4/100
# 1/1 [==============================] - 0s 8ms/step - loss: 24.7209 - mae: 24.7209
# Epoch 5/100
# 1/1 [==============================] - 0s 9ms/step - loss: 22.4806 - mae: 22.4806
# Epoch 6/100
# 1/1 [==============================] - 0s 10ms/step - loss: 20.3837 - mae: 20.3837
# Epoch 7/100
# 1/1 [==============================] - 0s 8ms/step - loss: 18.3785 - mae: 18.3785
# Epoch 8/100
# 1/1 [==============================] - 0s 7ms/step - loss: 16.4596 - mae: 16.4596
# Epoch 9/100
# 1/1 [==============================] - 0s 7ms/step - loss: 14.6272 - mae: 14.6272
# Epoch 10/100
# 1/1 [==============================] - 0s 7ms/step - loss: 12.9203 - mae: 12.9203
# Epoch 11/100
# 1/1 [==============================] - 0s 7ms/step - loss: 11.2739 - mae: 11.2739
# Epoch 12/100
# 1/1 [==============================] - 0s 6ms/step - loss: 9.7166 - mae: 9.7166
# Epoch 13/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.2271 - mae: 8.2271
# Epoch 14/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8337 - mae: 6.8337
# Epoch 15/100
# 1/1 [==============================] - 0s 6ms/step - loss: 5.5298 - mae: 5.5298
# Epoch 16/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3565 - mae: 4.3565
# Epoch 17/100
# 1/1 [==============================] - 0s 11ms/step - loss: 3.4159 - mae: 3.4159
# Epoch 18/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8857 - mae: 2.8857
# Epoch 19/100
# 1/1 [==============================] - 0s 7ms/step - loss: 3.1465 - mae: 3.1465
# Epoch 20/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.1555 - mae: 4.1555
# Epoch 21/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7633 - mae: 4.7633
# Epoch 22/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9800 - mae: 4.9800
# Epoch 23/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8786 - mae: 4.8786
# Epoch 24/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5228 - mae: 4.5228
# Epoch 25/100
# 1/1 [==============================] - 0s 7ms/step - loss: 3.9677 - mae: 3.9677
# Epoch 26/100
# 1/1 [==============================] - 0s 8ms/step - loss: 3.2601 - mae: 3.2601
# Epoch 27/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7564 - mae: 2.7564
# Epoch 28/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.6701 - mae: 2.6701
# Epoch 29/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.7781 - mae: 2.7781
# Epoch 30/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9490 - mae: 2.9490
# Epoch 31/100
# 1/1 [==============================] - 0s 6ms/step - loss: 3.1029 - mae: 3.1029
# Epoch 32/100
# 1/1 [==============================] - 0s 8ms/step - loss: 3.2273 - mae: 3.2273
# Epoch 33/100
# 1/1 [==============================] - 0s 7ms/step - loss: 3.2910 - mae: 3.2910
# Epoch 34/100
# 1/1 [==============================] - 0s 6ms/step - loss: 3.2980 - mae: 3.2980
# Epoch 35/100
# 1/1 [==============================] - 0s 7ms/step - loss: 3.2540 - mae: 3.2540
# Epoch 36/100
# 1/1 [==============================] - 0s 8ms/step - loss: 3.1637 - mae: 3.1637
# Epoch 37/100
# 1/1 [==============================] - 0s 7ms/step - loss: 3.0304 - mae: 3.0304
# Epoch 38/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8747 - mae: 2.8747
# Epoch 39/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.7039 - mae: 2.7039
# Epoch 40/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5547 - mae: 2.5547
# Epoch 41/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4340 - mae: 2.4340
# Epoch 42/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.3812 - mae: 2.3812
# Epoch 43/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4003 - mae: 2.4003
# Epoch 44/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4964 - mae: 2.4964
# Epoch 45/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5853 - mae: 2.5853
# Epoch 46/100
# 1/1 [==============================] - 0s 9ms/step - loss: 2.5848 - mae: 2.5848
# Epoch 47/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4666 - mae: 2.4666
# Epoch 48/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.3236 - mae: 2.3236
# Epoch 49/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2311 - mae: 2.2311
# Epoch 50/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1978 - mae: 2.1978
# Epoch 51/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.2033 - mae: 2.2033
# Epoch 52/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.2284 - mae: 2.2284
# Epoch 53/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2415 - mae: 2.2415
# Epoch 54/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.2382 - mae: 2.2382
# Epoch 55/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2079 - mae: 2.2079
# Epoch 56/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1530 - mae: 2.1530
# Epoch 57/100
# 1/1 [==============================] - 0s 10ms/step - loss: 2.0971 - mae: 2.0971
# Epoch 58/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0314 - mae: 2.0314
# Epoch 59/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9797 - mae: 1.9797
# Epoch 60/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.9477 - mae: 1.9477
# Epoch 61/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.9412 - mae: 1.9412
# Epoch 62/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9485 - mae: 1.9485
# Epoch 63/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9395 - mae: 1.9395
# Epoch 64/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9070 - mae: 1.9070
# Epoch 65/100
# 1/1 [==============================] - 0s 6ms/step - loss: 1.8534 - mae: 1.8534
# Epoch 66/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7959 - mae: 1.7959
# Epoch 67/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7556 - mae: 1.7556
# Epoch 68/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7333 - mae: 1.7333
# Epoch 69/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7191 - mae: 1.7191
# Epoch 70/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7029 - mae: 1.7029
# Epoch 71/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6767 - mae: 1.6767
# Epoch 72/100
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6365 - mae: 1.6365
# Epoch 73/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5975 - mae: 1.5975
# Epoch 74/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5549 - mae: 1.5549
# Epoch 75/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5221 - mae: 1.5221
# Epoch 76/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4978 - mae: 1.4978
# Epoch 77/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4767 - mae: 1.4767
# Epoch 78/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4491 - mae: 1.4491
# Epoch 79/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4158 - mae: 1.4158
# Epoch 80/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3773 - mae: 1.3773
# Epoch 81/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3356 - mae: 1.3356
# Epoch 82/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3038 - mae: 1.3038
# Epoch 83/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2725 - mae: 1.2725
# Epoch 84/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2436 - mae: 1.2436
# Epoch 85/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2093 - mae: 1.2093
# Epoch 86/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1732 - mae: 1.1732
# Epoch 87/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1396 - mae: 1.1396
# Epoch 88/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1055 - mae: 1.1055
# Epoch 89/100
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0749 - mae: 1.0749
# Epoch 90/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0407 - mae: 1.0407
# Epoch 91/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0023 - mae: 1.0023
# Epoch 92/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.9676 - mae: 0.9676
# Epoch 93/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.9326 - mae: 0.9326
# Epoch 94/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8972 - mae: 0.8972
# Epoch 95/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8614 - mae: 0.8614
# Epoch 96/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8267 - mae: 0.8267
# Epoch 97/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7882 - mae: 0.7882
# Epoch 98/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7507 - mae: 0.7507
# Epoch 99/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7127 - mae: 0.7127
# Epoch 100/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6750 - mae: 0.6750

# %%
model_1.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 4)                 8
#
#  dense_22 (Dense)            (None, 4)                 20
#
#  dense_23 (Dense)            (None, 4)                 20
#
#  dense_24 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 53
# Trainable params: 53
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model_1, show_shapes = True)

# %%
weight, bias = model_1.layers[3].get_weights()
print(weight, bias)
# Out:
# [[ 0.4385777 ]
#  [-0.8164318 ]
#  [-0.86801976]
#  [-0.7417164 ]] [-0.32443497]

# %% [markdown]
# ### 3. Import the Boston pricing dataset from TensorFlow `tf.keras.datasets` and model it.###

# %%
# Loading the data

(X_train, y_train), (X_test, y_test) = tf.keras.datasets.boston_housing.load_data(path='boston_housing.npz', test_split=0.2)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 0us/step

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
# Building a model

model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(1)
])

model_2.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate = 0.01),
    loss = tf.keras.losses.mse,
    metrics = ['mse']
)

history = model_2.fit(X_train_scaled, y_train, epochs = 200, verbose = False)

# %%
# Evaluating a model
model_2.evaluate(X_test_scaled, y_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 55.3694 - mse: 55.3694
# [55.36941909790039, 55.36941909790039]

# %%
# Plot loss curve

import pandas as pd

pd.DataFrame(history.history).plot()
# Out:
# <Axes: >
